# %%
# masukkan library yang akan digunakan
import pandas as pd
import numpy as nu
import matplotlib.pyplot as plt
import seaborn as sns

# melakukan pembacaan pada data yang akan digunakan 
# directory disesuaikan dengan lokasi file data yang digunakan
data = pa.read_csv('C://Users/User/Data Survey/Data_Survey.csv')

# melihat dimensi data 
data.shape
# Out:
# (206, 15)

# %%
# melihat info setiap kolom  
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 15 columns):
# Timestamp                                                        206 non-null object
# Username                                                         175 non-null object
# Harga makanan di Manado terjangkau                               206 non-null object
# Makanannya sepadan dengan harga yang harus dibayar (worth it)    206 non-null object
# Tinutuan menjadi makanan unggulan                                206 non-null object
# Nasi kuning menjadi makanan unggulan                             206 non-null object
# Perkedel Nike menjadi makanan unggulan                           206 non-null object
# Ikan woku menjadi makanan unggulan                               206 non-null object
# Nasi bambu (bulu) menjadi makanan unggulan                       206 non-null object
# cakalang abon/sous menjadi makanan unggulan                      206 non-null object
# ...

# %%
# menampilkan data teratas dari data yang dibaca
data.head(10)
# Out:
#                       Timestamp Username Harga makanan di Manado terjangkau  \
# 0  2019/11/05 12:55:41 PM GMT+8      NaN                                 CS
# 1  2019/11/05 12:56:35 PM GMT+8      NaN                                 CS
# 2  2019/11/05 12:56:54 PM GMT+8      NaN                                  S
# 3  2019/11/05 12:59:53 PM GMT+8      NaN                                 CS
# 4   2019/11/05 1:00:00 PM GMT+8      NaN                                  S
# 5   2019/11/05 1:00:57 PM GMT+8      NaN                                 CS
# 6   2019/11/05 1:01:54 PM GMT+8      NaN                                 CS
# 7   2019/11/05 1:02:01 PM GMT+8      NaN                                  S
# 8   2019/11/05 1:02:15 PM GMT+8      NaN                                 SS
# 9   2019/11/05 1:02:36 PM GMT+8      NaN                                 TS
#
#   Makanannya sepadan dengan harga yang harus dibayar (worth it)  \
# 0                                                 CS
# ...

# %%
# menampilkan data terbawah dari data yang dibaca
data.tail(10)
# Out:
#                         Timestamp                       Username  \
# 196   2019/11/12 9:46:37 PM GMT+8         loingnatasha@gmail.com
# 197   2019/11/12 9:50:53 PM GMT+8         ericgaskin32@gmail.com
# 198   2019/11/13 8:54:57 AM GMT+8      fabiola.motoh11@gmail.com
# 199   2019/11/13 9:08:03 AM GMT+8         kurnia.ksm93@gmail.com
# 200   2019/11/13 9:42:15 AM GMT+8  rahjaypelengkahu162@gmail.com
# 201  2019/11/13 10:23:01 AM GMT+8           maminawanm@gmail.com
# 202   2019/11/13 1:41:30 PM GMT+8    sheilaamrimanoppo@gmail.com
# 203   2019/11/13 4:32:41 PM GMT+8            riskoikho@gmail.com
# 204   2019/11/13 6:05:45 PM GMT+8          gianmamonto@gmail.com
# 205   2019/11/13 8:42:14 PM GMT+8   marcellapaputungan@gmail.com
#
#     Harga makanan di Manado terjangkau  \
# 196                                  S
# 197                                 CS
# 198                                  S
# 199                                 CS
# 200                                 CS
# ...

# %%
# melihat keseluruhan data survey
data.head(205)
# Out:
#                         Timestamp                         Username  \
# 0    2019/11/05 12:55:41 PM GMT+8                              NaN
# 1    2019/11/05 12:56:35 PM GMT+8                              NaN
# 2    2019/11/05 12:56:54 PM GMT+8                              NaN
# 3    2019/11/05 12:59:53 PM GMT+8                              NaN
# 4     2019/11/05 1:00:00 PM GMT+8                              NaN
# 5     2019/11/05 1:00:57 PM GMT+8                              NaN
# 6     2019/11/05 1:01:54 PM GMT+8                              NaN
# 7     2019/11/05 1:02:01 PM GMT+8                              NaN
# 8     2019/11/05 1:02:15 PM GMT+8                              NaN
# 9     2019/11/05 1:02:36 PM GMT+8                              NaN
# 10    2019/11/05 1:02:47 PM GMT+8                              NaN
# 11    2019/11/05 1:02:59 PM GMT+8                              NaN
# 12    2019/11/05 1:03:49 PM GMT+8                              NaN
# ...

# %%
# menampilkan diagram hasil Survey
# directory disesuaikan dengan lokasi file png
from IPython.display import Image, display

listOfImageNames = ['C://Users/User/Data Survey/Diagramhasilsurvey/1.png',
                    'C://Users/User/Data Survey/Diagramhasilsurvey/2.png',
                   'C://Users/User/Data Survey/Diagramhasilsurvey/3.png',
                   'C://Users/User/Data Survey/Diagramhasilsurvey/4.png',
                   'C://Users/User/Data Survey/Diagramhasilsurvey/5.png',
                   'C://Users/User/Data Survey/Diagramhasilsurvey/6.png',
                   'C://Users/User/Data Survey/Diagramhasilsurvey/7.png',
                   'C://Users/User/Data Survey/Diagramhasilsurvey/8.png',
                   'C://Users/User/Data Survey/Diagramhasilsurvey/9.png',
                   'C://Users/User/Data Survey/Diagramhasilsurvey/10.png',
                   'C://Users/User/Data Survey/Diagramhasilsurvey/11.png',
                   'C://Users/User/Data Survey/Diagramhasilsurvey/12.png',
                   'C://Users/User/Data Survey/Diagramhasilsurvey/13.png',]

for imageName in listOfImageNames:
    display(Image(filename=imageName))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-23dcd0786bcc> in <module>
#      16
#      17 for imageName in listOfImageNames:
# ---> 18     display(Image(filename=imageName))
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1195         self.unconfined = unconfined
#    1196         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1197                 metadata=metadata)
#    1198
#    1199         if self.width is None and self.metadata.get('width', {}):
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, metadata)
#     618             self.metadata = {}
#     619
# --> 620         self.reload()
#     621         self._check_data()
#     622
#
# ...

# %%
# pertanyaan dari survey kami tidak memiliki korelasi yang berarti
# menampilkan data korelasi antar feature
correlations = data.corr(method='kendall')
correlations
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Korelasi yang tinggi yang paling terang

f,ax = plt.subplots(figsize=(15,15))
sns.heatmap(correlations, annot=True, linewidths=.5, fmt='.3f', ax=ax)
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-d7fa54daf6bc> in <module>
#       2
#       3 f,ax = plt.subplots(figsize=(15,15))
# ----> 4 sns.heatmap(correlations, annot=True, linewidths=.5, fmt='.3f', ax=ax)
#       5 plt.show
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ...
